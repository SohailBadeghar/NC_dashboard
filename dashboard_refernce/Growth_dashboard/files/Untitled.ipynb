# %%
import pandas as pd

excel_file_path = '/home/neosoft/Desktop/dashboard_gene/dashboard_refernce/Growth_dashboard/files/Nc_planned_progress_path.xlsx'
# Read data from Excel
nc_progress_data = pd.read_excel(excel_file_path)

nc_progress_data
# Out:
#     Unnamed: 0                 Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN            NaN        NaN
# 1          NaN                Description     Short Name  Weightage
# 2          NaN           Overall Progress            NaN          1
# 3          NaN       Imagery & GCN Report     GCN Report       0.02
# 4          NaN             GCP Collection            GCP       0.05
# 5          NaN                         AT             AT   0.039994
# 6          NaN            Database Design       Database      0.005
# 7          NaN                        DSM            DSM   0.050113
# 8          NaN            Building Update   Building UPD   0.129963
# 9          NaN           Transport Update  Transport UPD   0.100019
# 10         NaN               Hydro Update      Hydro UPD   0.100019
# 11         NaN                        DTM            DTM   0.097985
# 12         NaN                    Contour        Contour   0.027996
# ...
